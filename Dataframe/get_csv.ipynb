# %%
import pandas as pd

df = pd.read_csv("../data/avocado.csv")

# df.head(5) 
 
# df["region"][:10]

chicago = df[df["region"] ==  "Chicago"]

chicago = chicago.set_index("Date").sort_values(by="Date")


chicago.head(15)
# Out:
#             AveragePrice  Total Volume      4046       4225       4770  \
# Date
# 2015-01-04          1.11     783068.03  30270.26  550752.19  124506.10
# 2015-01-04          1.49      17723.17   1189.35   15628.27       0.00
# 2015-01-11          1.15     802874.94  31239.94  558487.79  133848.57
# 2015-01-11          1.79      12915.74   1426.75   10900.10       0.00
# 2015-01-18          1.14     797741.43  24917.77  533717.99  140239.95
# 2015-01-18          1.81      12499.87   1154.81   10830.61       0.00
# 2015-01-25          1.22     745439.17  26117.56  488218.44  145882.24
# 2015-01-25          1.83      10951.51    711.63    9515.44       0.00
# 2015-02-01          0.91    1133491.66  50783.91  824745.44  164884.41
# 2015-02-01          1.52      14391.05   1363.35   11835.47       0.00
# 2015-02-08          1.13     729325.61  28216.83  499138.28  119634.41
# 2015-02-08          1.78       9910.84   1224.22    6971.06       0.00
# ...
